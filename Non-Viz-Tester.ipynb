# %%
import numpy
import mesa
from model import HumanitarianLogistics, COA
import matplotlib.pyplot as plt

# %%
canvas_width = 600
canvas_height = 400
num_azc = 3
num_cities = 3
grid_width = int(canvas_width / 4)
grid_height = int(canvas_height / 4)
Test = HumanitarianLogistics(100, 200, .05, 3, 3, .9, grid_width, grid_height)

# %%
for i in range(500):
    Test.step()
# Out:
# 301358
# no shock
# 301746
# no shock
# 301164
# no shock
# 300970
# no shock
# 302522
# no shock
# 301552
# no shock
# 302134
# no shock
# 301940
# no shock
# 302716
# shock
# Manageable
# Manageable
# 303104
# shock
# Manageable
# 303298
# shock
# Manageable
# Manageable
# 303104
# shock
# Manageable
# Manageable
# 305044
# shock
# Manageable
# Manageable
# 305044
# shock
# Manageable
# 304656
# shock
# Manageable
# Manageable
# 305044
# shock
# Manageable
# Manageable
# 308148
# shock
# Manageable
# 307954
# shock
# Manageable
# Manageable
# 308148
# shock
# Manageable
# Manageable
# 306984
# shock
# Manageable
# Manageable
# 312222
# shock
# Manageable
# 311252
# shock
# Manageable
# Manageable
# 312028
# shock
# Manageable
# Manageable
# 312222
# shock
# Manageable
# Manageable
# 317654
# shock
# Manageable
# Manageable
# 317460
# shock
# Manageable
# 316684
# shock
# Manageable
# Manageable
# 317654
# shock
# Manageable
# Manageable
# 324056
# shock
# Manageable
# Manageable
# 323474
# shock
# Manageable
# 325026
# shock
# Manageable
# Manageable
# 324832
# shock
# Manageable
# Manageable
# 332980
# shock
# Manageable
# Manageable
# 334144
# shock
# Manageable
# Manageable
# 327742
# shock
# Manageable
# 334338
# shock
# Manageable
# Manageable
# 330458
# shock
# Manageable
# 335308
# shock
# Manageable
# Manageable
# 337054
# shock
# Manageable
# Manageable
# 336666
# shock
# Manageable
# Manageable
# 335308
# shock
# Manageable
# 339964
# shock
# Manageable
# Manageable
# 341128
# shock
# Manageable
# Manageable
# 340934
# shock
# Manageable
# Manageable
# 348112
# shock
# Manageable
# Manageable
# 342098
# shock
# Manageable
# 347530
# shock
# Manageable
# Manageable
# 346754
# shock
# Manageable
# Manageable
# 351022
# shock
# Manageable
# 358976
# shock
# Manageable
# Manageable
# 358394
# shock
# Manageable
# Manageable
# 357036
# shock
# Manageable
# Manageable
# 374884
# shock
# Manageable
# Manageable
# 374690
# shock
# Manageable
# Manageable
# 360528
# shock
# Manageable
# 372944
# shock
# Manageable
# Manageable
# 372944
# shock
# Manageable
# 397582
# shock
# Manageable
# Manageable
# 395836
# shock
# Manageable
# Manageable
# 397194
# shock
# Manageable
# Manageable

# %%
coa = [agent for agent in Test.schedule.agents if
      type(agent) is COA and not agent.ta]

# %%
names = ['Consolidate', 'Invest', 'Segregate', 'Integrate']
hist = {name:0 for name in names}


for c in coa:
    for name in names:
        for act in c.actions:
            if act.name == name:
                hist[name] += act.counter
plt.bar(hist.keys(), hist.values())
plt.show()
